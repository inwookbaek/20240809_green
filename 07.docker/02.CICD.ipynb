# %% [markdown]
# # AWS lightsail
#
# - AWS ligtsale 참고사이트
#   - https://velog.io/@ckdwns9121/Github-Action을-이용해-AWS-Lightsail-CICD-파이프라인-구축하기-1편<br>
#   - https://velog.io/@ckdwns9121/Github-Action을-이용해-AWS-Lightsail-CICD-파이프라인-구축하기-2편<br>
#   - https://beaniejoy.tistory.com/95<br>
#
# ## 1. AWS lightsail 설치
#
# <div align="center">
#   <h3>1. create instance</h1>
#   <img src="./images/01.aws_lightsail_01.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_02.jpg" width="800px" height="500px"><br>
#
#   <h3>2. create SSH key pair</h1>
#   <img src="./images/01.aws_lightsail_03.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_04.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_05.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_06.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_07.jpg" width="800px" height="500px"><br>
#   <h6>다운로드 개인키(private key) - my_ssh_key.pem</h6>
#   <img src="./images/01.aws_lightsail_08.jpg" width="800px" height="500px"><br>
#   <h6>다운로드 공개키(default key) - LightsailDefaultKey-ap-northeast-2.pem</h6>
#   <img src="./images/01.aws_lightsail_10.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_11.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_12.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_13.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_14.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_15.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_16.jpg" width="800px" height="500px"><br>
#   <img src="./images/01.aws_lightsail_17.jpg" width="800px" height="500px"><br>
# </div>

# %% [markdown]
# ## 2. AWS lightsail ssh 관련사항
#
# ### 2-1 connect ssh (aws-lightsail)
#
# <div align="center">
#   <h3>1. create instance</h1>
#   <img src="./images/02.aws_lightsail_ssh_01.jpg" width="800px" height="500px"><br>
#   <img src="./images/02.aws_lightsail_ssh_02.jpg" width="800px" height="500px"><br>
#   <div align="left">
#     <ol>
#       <li>root 비밀번호생성하기</li>
#       <ul>
#         <li>sudo passwd root</li>
#         <li>new password : 12345</li>
#         <li>Retype new password : 12345</li>
#       </ul>
#       <li> ubuntu 비밀번호 생성하기</li>
#       <ul>
#         <li>sudo su -</li>
#         <li>passwd ubuntu</li>
#         <li>new password : 12345</li>
#         <li>Retype new password : 12345</li>
#       </ul>
#     </ol>
#   </div>
# </div>
#
# ### 2-2 connect ssh (windows powershell(admin mode))
#
# <div align="center">
#   <img src="./images/02.aws_lightsail_ssh_03.jpg" width="800px" height="500px"><br>
#   <div align="left">
#     <ol>
#       <li>다운로드된 폴더 외에서 실행할 경우 - 접속불가
#         <div align="center">
#           <img src="./images/02.aws_lightsail_ssh_04.jpg" width="800px" height="500px"><br>
#           <img src="./images/02.aws_lightsail_ssh_05.jpg" width="800px" height="500px"><br>
#           <img src="./images/02.aws_lightsail_ssh_06.jpg" width="800px" height="500px"><br>
#           <img src="./images/02.aws_lightsail_ssh_07.jpg" width="800px" height="500px"><br>
#         </div>
#       </li>
#       <li>다운로드 폴더 안에서 실행할 경우, 공개키 or 새로운 개인키로 실행할 경우 둘다 실행이 않되고 원개인키로는 바로 실행가능
#         <ul>
#           <li>해결방법 aws-lightsail의 ssh로 접속후 실행</li>
#           <li>sudo vi /etc/ssh/sshd_config.d/*.conf</li>
#           <li>PasswordAuthentication no => PasswordAuthentication yes 로 변경</li>
#           <li>sudo systemctl restart ssh.service</li>
#           <li>exit</li>
#         </ul>
#       </li>
#       <li>환경설정후 공개키 or 새로운 개인키 or 원개인키로 실행할 경우 모두 비번요구후 확인시 실행가능
#         <div align="center">
#           <img src="./images/02.aws_lightsail_ssh_08.jpg" width="800px" height="500px"><br>
#         </div>
#       </li>
#       <li>config파일 설정</li>
#         ```yml
#
#         Host aws
#           HostName 43.200.104.42
#           User ubuntu
#           IdentityFile .\my_ssh_key.pem
#
#         Host aws1
#           HostName 43.200.104.42
#           User ubuntu
#           IdentityFile .\my_ssh_key_2.pem
#
#         Host aws2
#           HostName 43.200.104.42
#           User ubuntu
#           IdentityFile .\LightsailDefaultKey-ap-northeast-2.pem
#
#         # 실행방법 : ssh aws
#         # 또는 ssh -i LightsailDefaultKey-ap-northeast-2.pem ubuntu@43.200.104.42
#         ```
#     </ol>
#   </div>
# </div>

# %% [markdown]
# # 2. JDK설치
#
# ##### sudo docker... 즉 sudo명령없이 사용 -> sudo u - > password 요구
# - passwd root : 비번변경(new, retype)
# - passwd ubuntu
# - sudo su - // 루트사용자로 변경
# - su ubuntu // 사용자로 변경
#
# ## 2.1. OpenJDK 17 설치 (참고 : https://wikidocs.net/252181)
# - sudo apt update
# - sudo apt install openjdk-17-jdk
#
# ## 2.2. 설치된 Java 버전확인
# - java -version
#
# ## 2.3. java설치경로 확인
# - 기본경로 : /usr/lib/jvm/java-17-openjdk-amd64/bin/java
#
# ## 2.4. JAVA_HOME 환경변수 설정
#
# ### 2.4.1. 환경변수 파일 수정:
# - sudo vi /etc/environment
#
# ### 2.4.2. 파일에 JAVA_HOME 추가:
#
# - 기본값 : PATH="/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin"
# - 추가   : JAVA_HOME="/usr/lib/jvm/java-17-openjdk-amd64"
#
# ## 2.5. 환경변수 적용 및 확인
# - source 명령어를 사용하여 변경된 내용을 적용하고, JAVA_HOME 환경변수가 올바르게 설정되었는지 확인
# - source /etc/environment
# - echo $JAVA_HOME
#
# ## 2.6. Java 삭제 (선택사항)
# - 설치된 Java를 제거하려면 다음 명령어를 사용합니다.
# - sudo apt remove openjdk-17-jdk

# %% [markdown]
# # 3. Docker 설치
#
# - 설치 : https://docs.docker.com/engine/install/ubuntu/
#
# ## 3-1 Set up Docker's apt repository.
# ```bash
# # Add Docker's official GPG key:
# sudo apt-get update
#
# sudo apt-get install ca-certificates curl
#
# sudo install -m 0755 -d /etc/apt/keyrings
#
# sudo curl -fsSL https://download.docker.com/linux/ubuntu/gpg -o /etc/apt/keyrings/docker.asc
#
# sudo chmod a+r /etc/apt/keyrings/docker.asc
#
# # Add the repository to Apt sources:
# echo \
#   "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.asc] https://download.docker.com/linux/ubuntu \
#   $(. /etc/os-release && echo "$VERSION_CODENAME") stable" | \
#   sudo tee /etc/apt/sources.list.d/docker.list > /dev/null
#
# sudo apt-get update
# ```
#
# ## 3-2 Install the Docker packages.
# ```bash
# sudo apt-get install docker-ce docker-ce-cli containerd.io docker-buildx-plugin docker-compose-plugin
# ```
#
# ## 3-3 Hello World
# ```bash
# sudo docker run hello-world
# ```
#
# ## 3-4 Manage Docker as a non-root user
#
# ### 3-4-1 Create the docker group
# - sudo groupadd docker
#
# ### 3-4-2 Add your user to the docker group.
# - sudo usermod -aG docker $USER
#
# ### 3-4-3 Log out and log back in so that your group membership is re-evaluated.
# - newgrp docker
#
# ### 4. Verify that you can run docker commands without sudo.
# - docker run hello-world

# %% [markdown]
# ## 4. Jenkins 설치 -
#
# ## 4.1 ubuntu os에 직접설치하기
#
# - 참고사이트
#   - jenkins : https://www.jenkins.io/doc/book/installing/linux/
#   - 블로그 : https://myminju.tistory.com/115
#
# ### 4.1.1 Jenkins 설치
#
# - sudo wget -O /usr/share/keyrings/jenkins-keyring.asc https://pkg.jenkins.io/debian-stable/jenkins.io-2023.key
# - echo "deb [signed-by=/usr/share/keyrings/jenkins-keyring.asc]" https://pkg.jenkins.io/debian-stable binary/ | sudo tee /etc/apt/sources.list.d/jenkins.list > /dev/null
# - sudo apt-get update
# - sudo apt-get install jenkins
#
# ### 4.1.2 초기패스워드 확인
# - sudo ls -al /var/lib/jenkins/secrets/
# - sudo cat /var/lib/jenkins/secrets/initialAdminPassword
#   - 패스워드복사
#
# ### 4.1.3 젠킨스 설치
#
# <div align="center">
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_01_initial password.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_02_create admin user.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_03_url.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_04_jenkins_start_url.jpg" width="800px" height="500px"><br>
# </div>
#
# ### 4.1.4 Jenkins 관련명령들
#
# - 환경정보 : sudo cat /lib/systemd/system/jenkins.service
# - port변경 : sudo vi /lib/systemd/system/jenkins.service
#   - [Service]
#     - Environment="JENKINS_PORT=8081"
#
# - start jenkins
#   - sudo systemctl enable jenkins
#   - sudo systemctl start jenkins
#   - sudo systemctl status jenkins
#   - sudo systemctl restart jenkins
#
# - 방화벽(참고 : https://webdir.tistory.com/206)
#   - sudo ufw status
#   - sudo ufw enable
#   - sudo ufw allow 8080 : 8080포트 허용
#   - sudo ufw allow 22/tcp : tcp 22 port허용
#   - sudo ufw allow 22/udp : udp 22 port허용
#   - sudo ufw deny 22
#
# - task kill
# ps -ef | grep 'app'
# kill -9 [pid]
#
# ### 4.1.5 젠킨스 환경 설정
#
# <div align="center">
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_05_jenkins_management.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_06_system.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_07_github.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_08_github_credentials.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_09_github_persnal_token.jpg" width="800px" height="500px"><br>
#   <div align="left">
#     <ul>
#       <li>Kind   : Scret text</li>
#       <li>Secret : your github personal access token</li>
#       <li>ID : webapp (Jenkins Credentials Provider ID(젠킨스에서 사용할 임의의 아이디))</li>
#       <li>Description : github personal access token by webapp ( ID 설명)</li>
#     </ul>
#   </div>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_10_github_access_test.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_11_credentials_01.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_11_credentials_02.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_11_credentials_03.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_12_plugins_01.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_12_plugins_02_stage_view.jpg" width="800px" height="500px"><br>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_12_plugins_03_GitHub Integration.jpg" width="800px" height="500px"><br>
#   <h6 style="color: green">GitHub Integration 플러그인 없어도 실행이 된다. 설치없이 진행해 보고 실행이 않될 경우에 설치하고 실행할 것</h6>
#   <img src="./images/04.ubuntu에 직접설치하기 - jenkins_setup_12_plugins_03_jenkins_restart.jpg" width="800px" height="500px"><br>
# </div>

# %% [markdown]
# ## 5 ci/cd build
#
# ### 5.1 github personal access token
#
# <div align="center">
#   <img src="./images/05.01.github setup_01.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.01.github setup_02.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.01.github setup_03.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.01.github setup_04.jpg" width="800px" height="500px"><br>
#   <h5>Generate token 버튼 클릭</h5>
# </div>
#
# ### 5.2 github webhooks
#
# <div align="center">
#   <img src="./images/05.02.github setup_01.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.02.github setup_02.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.02.github setup_03.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.02.github setup_04.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.02.github setup_05.jpg" width="800px" height="500px"><br>
# </div>
#
# ### 5.3 jenkins job build
#
# <div align="center">
#   <img src="./images/05.03.jenkins_build 생성_01.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.03.jenkins_build 생성_02.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.03.jenkins_build 생성_03.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.03.jenkins_build 생성_04.jpg" width="800px" height="500px"><br>
# </div>
#
#
#
# #### 5.3.1 jenkins pipeline에서 docker명령 실행
#
# - Docker 소켓의 권한을 확인
#   - ls -l /var/run/docker.sock
#   - 결과 : srw-rw---- 1 root docker 0 Jan  8 04:53 /var/run/docker.sock
#
# - Docker 사용자 그룹에 Jenkins 추가 후 재시작 & reboot
#   - sudo usermod -aG docker jenkins
#   - sudo systemctl restart jenkins
#   - sudo systemctl restart docker
#   - sudo reboot
#
# #### 5.3.2 jenkins pipeline
#
# ```groovy
# pipeline {
#     agent any
#
#     environment {
#         PORT_ADMIN = '8090'
#     }
#
#     stages {
#         stage('Clone Repository') {
#             steps {
#                 script {
#                     // 클론할 디렉토리를 명시적으로 지정
#                     // -d: 지정된 경로가 디렉토리인지 확인.
#                     // [ ! -d "myproject" ] : "myproject"가 존재하지 않거나 디렉토리가 아닌 경우 참(true).
#                     sh '''
#                     if [ ! -d "myproject" ]; then
#                         echo "myproject directory is not exist."
#                     else
#                     echo "Repository already cloned in myproject directory."
#                         rm -rf ./myproject
#                     fi
#
#                     git clone -b master https://github.com/inwookbaek/20240809_green_cicd.git myproject
#                     '''
#                 }
#             }
#         }
#
#         stage('Check if App is Running') {
#             steps {
#                 script {
#                     sh '''
#                     # Check if app.jar is running
#                     if pgrep -f app.jar > /dev/null; then
#                         # 프로세스 죽이기
#                         pkill -9 -f app.jar
#                     else
#                         echo "app.jar is not running."
#                     fi
#                     '''
#                 }
#             }
#         }
#
#         stage('Change Directory and SpringBoot App Build') {
#             steps {
#                 script {
#                     // Change to the "myproject" directory and perform a task
#                     sh '''
#                     cd myproject
#                     # pwd  # 확인용: 현재 디렉토리 출력
#                     # ls   # 확인용: 디렉토리 내용 출력
#
#                     # ./gradlew 실행권한 부여
#                     chmod +x ./gradlew
#
#                     # jar build
#                     ./gradlew clean build
#
#                     # 필요한 빌드 명령 실행 (예: Docker 빌드, Gradle, Maven 등)
#                     # 예: Docker 빌드
#                     # docker build -t myimage:latest .
#                     '''
#                 }
#             }
#         }
#
#         stage('Run Java App in Background') {
#             steps {
#                 script {
#                     sh '''
#                     # Navigate to the project directory
#                     cd ./myproject/build/libs
#                     # pwd
#                     # ls
#
#                     # Run the Java application in the background
#                     # nohup은 no hang up 의 약자 입니다. 해석 그대로 "끊지마!" 의미
#                     # 중단 없이 실행하고자 하는 프로그램 명령어 앞에 "nohup" 만 붙여주면 된다.
#                     # 참고 사이트 : https://joonyon.tistory.com/entry/쉽게-설명한-nohup-과-백그라운드-명령어-사용법
#                     # 0 : 표준 입력/ 1 : 표준 출력 / 2 : 표준 에러
#                     # 2>&1 : 표준출력과 표준에러를 같은 파일에 쓰기
#                     export JENKINS_NODE_COOKIE=dontKillMe
#                     nohup java -jar app.jar > app.log 2>&1 &
#                     # nohup java -jar $WORKSPACE/myproject/build/libs/app.jar > $WORKSPACE/myproject/build/libs/app.log 2>&1 &
#                     # nohup java -Dserver.port=${PORT_ADMIN} -Dspring.profiles.active=dev -Dfile.encoding=UTF-8 -jar app.jar > app.log 2>&1 &
#
#                     # Print confirmation
#                     echo "Java application started in the background."
#                     '''
#                 }
#             }
#         }
#         }
#     }
# }
# ```
#
# ### 5.4 git push
#
# #### 5.4.1 직접 - build now
#
# <div align="center">
#   <img src="./images/05.04.git push_01.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.04.git push_02.jpg" width="800px" height="500px"><br>
# </div>
#
# #### 5.4.2 git push
#
# <div align="center">
#   <img src="./images/05.04.git push_01.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.04.git push_02.jpg" width="800px" height="500px"><br>
#   <img src="./images/05.04.git push_03.jpg" width="800px" height="500px"><br>
# </div>

# %% [markdown]
# # 6. ngrok
#
# ## 1. ngrok download & install
# ## 2. sesseion expire
#    - ngrok는 session유지시간이 8시간, 이후 ngrok를 재실행해야 하며 url이 변경된다.
#    - session을 8시간 이상 유지가 필요한 경우 회원가입후 auth token을 복사한 후 ngrok 실행
# ## 3. ngrok 재실행
#
#    - ngrok config add-authtoken 2bn5ZmhInWPmnfkozRyl0YHvCKY_6mt3o4naqpMeuSJRXRLbe
#    - ngrok.yml
#    ```yml
#    agent:
# 	    authtoken: your token
#    ```
#    - ngrok http 8090
#    <div align="center">
#       <img src="./images/06.docker_01_ngrok run.jpg" width="800px" height="500px"><br>
#       <img src="./images/06.docker_02_http connect.jpg" width="800px" height="500px"><br>
#     </div>
